# %% [markdown]
# Learning Python-pandas

# %% [markdown]
# Creating,Reading and Writing

# %%
import pandas as pd

# %% [markdown]
# Two objects in pandas *DataFrame* and *Series*

# %% [markdown]
# **DataFrame**
#
# A DataFrame is a table. It contains an array of individual entries, each of which has a certain value. Each entry corresponds to a row (or record) and a column.
#
# For example, consider the following simple DataFrame:

# %%
pd.DataFrame({'Yes':[12,64], 'No':[50,21]})
# Out:
#    Yes  No
# 0   12  50
# 1   64  21

# %% [markdown]
# DataFrame can also can also has strings apart from integers here is an example:

# %%
pd.DataFrame({'Michael':['I want ice cream.','I want cookies'],'Nikihta':['No you may not.','I can get cookie for you']})
# Out:
#              Michael                   Nikihta
# 0  I want ice cream.           No you may not.
# 1     I want cookies  I can get cookie for you

# %% [markdown]
# The dictionary-list constructor assigns values to the column labels, but just uses an ascending count from 0 (0, 1, 2, 3, ...) for the row labels. Sometimes this is OK, but oftentimes we will want to assign these labels ourselves.
#
# The list of row labels used in a DataFrame is known as an Index. We can assign values to it by using an index parameter in our constructor:

# %%
pd.DataFrame({'Michael':['I want Ice-Cream','I want Coockies'],'Nikhitha':['No you may not','Ok i will get cookies']},
             index = ['Product 1','Product 2'])
# Out:
#                     Michael               Nikhitha
# Product 1  I want Ice-Cream         No you may not
# Product 2   I want Coockies  Ok i will get cookies

# %% [markdown]
# **Series**
#
# A Series, by contrast, is a sequence of data values. If a DataFrame is a table, a Series is a list. And in fact you can create one with nothing more than a list:

# %%
pd.Series([1,2,3,7,8,8])
# Out:
# 0    1
# 1    2
# 2    3
# 3    7
# 4    8
# 5    8
# dtype: int64

# %% [markdown]
#  Series is, in essence, a single column of a DataFrame. So you can assign row labels to the Series the same way as before, using an index parameter.

# %%
pd.Series([28,25,20],index = ['Age of Amal','Age of Bimal','Age of Nikhitha'])
# Out:
# Age of Amal        28
# Age of Bimal       25
# Age of Nikhitha    20
# dtype: int64

# %% [markdown]
# The Series and the DataFrame are intimately related. It's helpful to think of a DataFrame as actually being just a bunch of Series "glued together".

# %% [markdown]
# **Reading data files**

# %%
wine = pd.read_csv("/content/sample_data/california_housing_test.csv")

# %% [markdown]
# We can use the shape attribute to check how large the resulting DataFrame is:

# %%
wine.shape
# Out:
# (3000, 9)

# %% [markdown]
# So our new DataFrame has 3000 records split across 9 different columns.
#
#
#
# We can examine the contents of the resultant DataFrame using the head() command, which grabs the first five rows:

# %%
wine.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0
